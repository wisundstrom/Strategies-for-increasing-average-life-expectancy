# %%
import pandas as pd
import numpy as np
from data_clean import data_clean
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.pipeline import Pipeline, make_pipeline

X_train_temp = pd.read_csv('./data/dirty_X_train.csv',index_col = 0)
y_train_temp = pd.read_csv('./data/dirty_y_train.csv',index_col = 0)

X_train = data_clean(X_train_temp,'x')
y_train = data_clean(y_train_temp,'y')
X_train.describe()
# Out:
#        Population_Size          LBW    Premature     Under_18      Over_40  \
# count     2.512000e+03  2512.000000  2512.000000  2512.000000  2512.000000
# mean      8.769437e+04     7.553258    11.861193     4.718327     1.734012
# std       2.360592e+05     1.826447     2.370688     2.243217     0.875945
# min       6.200000e+01     2.100000     5.100000     0.500000     0.200000
# 25%       1.115675e+04     6.300000    10.200000     3.000000     1.100000
# 50%       2.462000e+04     7.400000    11.700000     4.400000     1.600000
# 75%       6.209900e+04     8.500000    13.200000     5.900000     2.000000
# max       3.693050e+06    15.600000    23.500000    14.500000     9.100000
#
#          Late_Care          MVA      Suicide  No_HS_Diploma   Unemployed  \
# count  2512.000000  2512.000000  2512.000000    2512.000000  2512.000000
# mean     17.759909    25.855951    13.583805      15.047826     3.414327
# std       6.577779    11.158072     4.925690       5.794748    39.952031
# min       3.300000     3.900000     4.500000       1.880000     1.060000
# 25%      13.200000    18.100000    11.000000      10.810000     2.130000
# 50%      17.100000    25.200000    13.583805      13.980000     2.520000
# 75%      21.200000    31.700000    14.800000      19.125000     2.970000
# max      53.500000   122.200000    91.300000      59.460000  2004.680000
#
#            ...       Recent_Drug_Use  No_Exercise  Few_Fruit_Veg  \
# count      ...           2512.000000  2512.000000    2512.000000
# mean       ...              5.203276    26.403848      78.955219
# std        ...              1.113533     5.535899       3.993780
# min        ...              2.810000     8.300000      63.100000
# 25%        ...              4.450000    23.775000      78.100000
# 50%        ...              5.060000    26.403848      78.955219
# 75%        ...              5.730000    28.500000      80.025000
# max        ...             11.300000    52.400000      96.400000
#
#        High_Blood_Pres     Diabetes     Uninsured  Elderly_Medicare  \
# count      2512.000000  2512.000000   2512.000000       2512.000000
# mean         26.527960     7.817307     18.198280      10334.172289
# std           3.752052     2.601846    206.329284      25248.777632
# min           7.200000     0.500000      2.090000         11.000000
# 25%          26.527960     6.200000     10.477500       1636.000000
# 50%          26.527960     7.817307     13.300000       3482.000000
# 75%          26.527960     9.100000     17.002500       8070.500000
# max          47.100000    20.800000  10352.290000     337774.000000
#
#        Disabled_Medicare  Prim_Care_Phys_Rate  Dentist_Rate
# count        2512.000000          2512.000000   2512.000000
# mean         1802.975492            57.256210     32.086340
# std          3946.463551            45.584476     21.937147
# min            12.000000             0.000000      0.000000
# 25%           286.000000            30.300000     18.475000
# 50%           688.500000            50.200000     29.800000
# 75%          1686.500000            74.525000     43.300000
# max         54933.000000           581.200000    377.900000
#
# [8 rows x 22 columns]

# %%
pipe = Pipeline([
    ('sc', StandardScaler() ),
    ('elastic', ElasticNet(max_iter=10000) )
])

params = {
    'elastic__alpha': [.001, .025, .05,.1, .5,.75, 1, 2, 5, 10],
    'elastic__l1_ratio' : [.1, .5, .7, .9, .95, .99, 1]
}

search= GridSearchCV(estimator=pipe,
                    param_grid=params,
                    cv=5,
                    return_train_score=True
                    )
search.fit(X_train, y_train)
# Out:
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3148739041184854, tolerance: 0.8171404269235609
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.917166339588221, tolerance: 0.8064680995024875
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.724211438860948, tolerance: 0.7954721426711068
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.392240253176169, tolerance: 0.7672798638183584
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.865733346419347, tolerance: 0.8171404269235609
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.116309686124623, tolerance: 0.8064680995024875
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.701925227795073, tolerance: 0.7954721426711068
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.075924455223685, tolerance: 0.7672798638183584
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.634995765821259, tolerance: 0.8171404269235609
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.544908965854574, tolerance: 0.8064680995024875
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17.37497338448975, tolerance: 0.7954721426711068
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.503618389273015, tolerance: 0.7672798638183584
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.154138421622974, tolerance: 0.8171404269235609
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.32165364575576, tolerance: 0.8064680995024875
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.55665109005531, tolerance: 0.7954721426711068
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.592190859018501, tolerance: 0.7672798638183584
#   positive)
# /home/will/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('sc',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('elastic',
#                                         ElasticNet(alpha=1.0, copy_X=True,
#                                                    fit_intercept=True,
#                                                    l1_ratio=0.5, max_iter=5000,
#                                                    normalize=False,
#                                                    positive=False,
#                                                    precompute=False,
#                                                    random_state=None,
#                                                    selection='cyclic',
#                                                    tol=0.0001,
#                                                    warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'elastic__alpha': [0.001, 0.025, 0.05, 0.1, 0.5, 0.75,
#                                             1, 2, 5, 10],
#                          'elastic__l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99,
#                                                1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=0)

# %%
search.best_index_, search.best_params_, search.best_score_
# Out:
# (1, {'lasso__alpha': 0.5}, 0.47866782705026845)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2512 entries, 2559 to 2311
# Data columns (total 22 columns):
# Population_Size        2512 non-null float64
# LBW                    2512 non-null float64
# Premature              2512 non-null float64
# Under_18               2512 non-null float64
# Over_40                2512 non-null float64
# Late_Care              2512 non-null float64
# MVA                    2512 non-null float64
# Suicide                2512 non-null float64
# No_HS_Diploma          2512 non-null float64
# Unemployed             2512 non-null float64
# Sev_Work_Disabled      2512 non-null float64
# Major_Depression       2512 non-null float64
# Recent_Drug_Use        2512 non-null float64
# No_Exercise            2512 non-null float64
# Few_Fruit_Veg          2512 non-null float64
# High_Blood_Pres        2512 non-null float64
# Diabetes               2512 non-null float64
# Uninsured              2512 non-null float64
# Elderly_Medicare       2512 non-null float64
# Disabled_Medicare      2512 non-null float64
# Prim_Care_Phys_Rate    2512 non-null float64
# Dentist_Rate           2512 non-null float64
# dtypes: float64(22)
# memory usage: 451.4 KB

# %%
CV=pd.DataFrame(search.cv_results_)
CV2=CV.sort_values('rank_test_score')
CV2.head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 30       0.004439      0.000329         0.001854        0.000035
# 29       0.004301      0.000078         0.001809        0.000048
# 36       0.004279      0.000048         0.001855        0.000104
# 31       0.004500      0.000252         0.001849        0.000056
# 32       0.005244      0.000936         0.002423        0.000347
#
#    param_elastic__alpha param_elastic__l1_ratio  \
# 30                  0.5                     0.7
# 29                  0.5                     0.5
# 36                 0.75                     0.5
# 31                  0.5                     0.9
# 32                  0.5                    0.95
#
#                                                params  split0_test_score  \
# 30  {'elastic__alpha': 0.5, 'elastic__l1_ratio': 0.7}           0.546338
# 29  {'elastic__alpha': 0.5, 'elastic__l1_ratio': 0.5}           0.573543
# 36  {'elastic__alpha': 0.75, 'elastic__l1_ratio': ...           0.524828
# 31  {'elastic__alpha': 0.5, 'elastic__l1_ratio': 0.9}           0.515693
# 32  {'elastic__alpha': 0.5, 'elastic__l1_ratio': 0...           0.507251
#
#     split1_test_score  split2_test_score       ...         mean_test_score  \
# 30           0.472051           0.513078       ...                0.530874
# 29           0.304124           0.547369       ...                0.522163
# 36           0.450020           0.496480       ...                0.507413
# 31           0.442989           0.480949       ...                0.497650
# 32           0.434963           0.471630       ...                0.488493
#
#     std_test_score  rank_test_score  split0_train_score  split1_train_score  \
# 30        0.035468                1            0.539334            0.550746
# 29        0.110714                2            0.569983            0.579659
# 36        0.032740                3            0.515587            0.525043
# 31        0.033106                4            0.507093            0.516705
# 32        0.032667                5            0.498605            0.507485
#
#     split2_train_score  split3_train_score  split4_train_score  \
# 30            0.543297            0.522606            0.524365
# 29            0.573342            0.553962            0.556704
# 36            0.519103            0.498730            0.499786
# 31            0.513192            0.487723            0.487891
# 32            0.504686            0.479043            0.478716
#
#     mean_train_score  std_train_score
# 30          0.536070         0.010923
# 29          0.566730         0.009849
# 36          0.511650         0.010565
# 31          0.502521         0.012401
# 32          0.493707         0.012443
#
# [5 rows x 22 columns]

# %%
rid=ElasticNet(alpha=.5, l1_ratio=.7)
rid.fit(X_train, y_train)
coeffs=rid.coef_.tolist()
c_ind=list(range(26))
# coeffs=coeffs[0]
coeffs_index=list(zip(coeffs,c_ind))
coeffs_index.sort()
coeffs_index
# Out:
# [(-0.09976381110364435, 1),
#  (-0.09688875034218988, 2),
#  (-0.09503425045332037, 3),
#  (-0.08485517794569006, 8),
#  (-0.04938941620750586, 13),
#  (-0.025082345590590947, 6),
#  (-0.02478096875324685, 16),
#  (-0.015007758383329227, 15),
#  (-0.005928858440404433, 14),
#  (-0.000807437724778557, 20),
#  (-0.0006498767967075317, 10),
#  (-0.00034414094427739477, 19),
#  (0.0, 4),
#  (0.0, 5),
#  (-0.0, 7),
#  (-0.0, 9),
#  (-0.0, 11),
#  (-0.0, 12),
#  (1.0718092817318553e-06, 0),
#  (4.103907365802686e-05, 18),
#  (0.000760423877920998, 17),
#  (0.002033274096102877, 21)]

# %%
X_train.columns[13]
# Out:
# 'No_Exercise'

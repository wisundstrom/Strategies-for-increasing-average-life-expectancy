# %%
import pandas as pd
import seaborn as sns
from data_clean import data_clean

# %%
#data_cleaning
X_train = pd.read_csv('./data/dirty_X_train.csv',index_col = 0)
y_train = pd.read_csv('./data/dirty_y_train.csv',index_col = 0)

# %%
X_train.head()
# Out:
#       Population_Size  Poverty  Age_19_Under  Age_19_64  Age_65_84  \
# 583             37931     11.8          23.2       59.9       14.2
# 1856          1593200     18.6          18.3       69.0       10.7
# 1897            89162     13.3          21.6       60.4       16.6
# 1610            83172     12.6          23.2       63.7       11.4
# 2022             4291     11.0          21.6       53.9       19.7
#
#       Age_85_and_Over  White  Black  Native_American  Asian  ...  Meas_Ind  \
# 583               2.8   91.6    0.5              5.6    1.0  ...         3
# 1856              2.0   66.5   19.8              0.7   10.9  ...         3
# 1897              1.4   85.4   12.6              0.8    0.5  ...         3
# 1610              1.7   96.7    0.3              1.2    0.5  ...         3
# 2022              4.9   97.7    0.3              1.4    0.4  ...         3
#
#       Meas_Exp  Pap_Smear  Mammogram  Proctoscopy  Pneumo_Vax  Flu_Vac  \
# ...

# %%
X_train = data_clean(X_train,'x')
y_train = data_clean(y_train,'y')
# Out:
# C:\Users\Melissa\Documents\DS_Bootcamp\MOD-4\mod4\data_clean.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dataset[c][dataset[c].isin([-9999,-2222,-2222.2,-2,-1111.1,-1111,-1])]= None

# %%
y_train.describe()
# Out:
#                ALE
# count  2512.000000
# mean     76.341036
# std       2.004616
# min      66.600000
# 25%      75.000000
# 50%      76.600000
# 75%      77.700000
# max      81.300000

# %%
X_train.describe().T
# Out:
#                       count          mean            std   min        25%  \
# Population_Size      2512.0  92773.937500  296811.738422  62.0  11464.000
# Poverty              2512.0     13.323248       4.883453   3.0      9.800
# Age_19_Under         2512.0     24.829339       3.212671  13.4     22.800
# Age_19_64            2512.0     60.290645       3.357145  47.6     58.300
# Age_65_84            2512.0     12.759275       3.307178   2.1     10.700
# Age_85_and_Over      2512.0      2.122412       0.958852   0.1      1.500
# White                2512.0     87.096815      16.112354   4.7     82.900
# Black                2512.0      8.949045      14.561824   0.0      0.500
# Native_American      2512.0      1.946178       7.499085   0.0      0.200
# Asian                2512.0      1.099363       2.651038   0.0      0.300
# Hispanic             2512.0      6.955533      12.418068   0.0      1.100
# Premature            2512.0     11.862895       2.398627   5.2     10.200
# ...
